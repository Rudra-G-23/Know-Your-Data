# %%
import numpy as np
import seaborn as sns
import missingno as mg

# %%
df = sns.load_dataset('iris')
df.sample(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 8             4.4          2.9           1.4          0.2     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 101           5.8          2.7           5.1          1.9  virginica

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# some missing value added in dataset
df['petal_length'].loc[np.random.randint(0, 150, 40)] = np.nan
df['petal_width'].loc[np.random.randint(0, 150, 5)] = np.nan
df['sepal_length'].loc[np.random.randint(0, 150, 60)] = np.nan
df['species'].loc[np.random.randint(0, 150, )] = np.nan

# %%
mg.dendrogram(df)
# Out:
# <Axes: >

# %%
mg.bar(df, color='purple')
# Out:
# <Axes: >

# %%
mg.heatmap(df)
# Out:
# <Axes: >

# %%
mg.matrix(df)
# Out:
# <Axes: >

# %%
mg.nullity_filter(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             NaN          3.5           NaN          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           NaN          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           NaN          3.0           5.2          2.3  virginica
# 146           6.3          2.5           NaN          1.9  virginica
# 147           NaN          3.0           5.2          2.0  virginica
# 148           NaN          3.4           5.4          2.3  virginica
# 149           5.9          3.0           NaN          1.8  virginica
#
# [150 rows x 5 columns]

# %%
mg.nullity_sort(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             NaN          3.5           NaN          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           NaN          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           NaN          3.0           5.2          2.3  virginica
# 146           6.3          2.5           NaN          1.9  virginica
# 147           NaN          3.0           5.2          2.0  virginica
# 148           NaN          3.4           5.4          2.3  virginica
# 149           5.9          3.0           NaN          1.8  virginica
#
# [150 rows x 5 columns]
